# %%
# %matplotlib inline
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ### File Descriptions
#
# - training.csv - Training set of 250000 events, with an ID column, 30 feature columns, a weight column and a label column.
# - test.csv - Test set of 550000 events with an ID column and 30 feature columns.
# - random_submission - Sample submission file in the correct format. File format is described on the Evaluation page.
# - HiggsBosonCompetition_AMSMetric - Python script to calculate the competition evaluation metric.
#
# For detailed information on the semantics of the features, labels, and weights, see the [technical documentation](http://higgsml.lal.in2p3.fr/documentation/) from the LAL website on the task.
#
# #### Some details to get started:
#
# - all variables are floating point, except PRI_jet_num which is integer
# - variables prefixed with PRI (for PRImitives) are “raw” quantities about the bunch collision as measured by the detector.
# - variables prefixed with DER (for DERived) are quantities computed from the primitive features, which were selected by the physicists of ATLAS
# - it can happen that for some entries some variables are meaningless or cannot be computed; in this case, their value is −999.0, which is outside the normal range of all variables
# - Signal events have only 4 possible weights, which comes from different mechanisms for the Higgs boson production. Thus, the problem can trivially be cast into a 5-class classification problem.
# - For background events, the weight distribution shows spikes plus a few bumps. Each of these cases corresponds to a different physics process (and thus has a different underlying distribution), and therefore may be considered as a potential new class.

# %%
import pandas as pd
train = pd.read_csv("train.csv", index_col='EventId')
test = pd.read_csv("test.csv", index_col='EventId')
# print train.shape, test.shape
# Out:
# (250000, 32) (550000, 30)

# %%
# boxplot each column
cols = list(set(train.columns) - set(['Label', 'Weight']))
for col in cols:
    train.boxplot(column=col, by='Label')
    show()
    test.boxplot(column=col)
    show()

# %% [markdown]
# ### Split data and build submodels
#
# - based on -999 patterns
# - based on `PRI_jet_num`?
#
# ### What to predict?
#
# - binary classification
# - multiclass classification (subclasses of background or signal)

# %%
# remove outliers in training data
# outliers: PRI_met & DER_pt_h & DER_pt_tot > 2500, a single data row
train = train[train['PRI_met'] <= 2500]
# check missing values other than -999, fortunately none
from numpy import isfinite
assert all(train[cols+['Weight']].applymap(isfinite).apply(all, axis=0))
assert all(test[cols].applymap(isfinite).apply(all, axis=0))

# %%
# find all possible -999 patterns in training and testing data
# luckily train and test data share the same -999 patterns
print train[cols].applymap(lambda x:str(int(x == -999))).apply(sum, axis=1).unique()
print test[cols].applymap(lambda x:str(int(x == -999))).apply(sum, axis=1).unique()
# Out:
# ['000000000000000000000000000000' '000011010000110100000000100000'
#  '001011010000110100000000100000' '010011010000110100001010100000'
#  '011011010000110100001010100000' '001000000000000000000000000000']
# ['011011010000110100001010100000' '000011010000110100000000100000'
#  '010011010000110100001010100000' '000000000000000000000000000000'
#  '001011010000110100000000100000' '001000000000000000000000000000']

# %%
# build sub-ensemble models: SGD, RF, LR, SVM, VW, blended by RF
